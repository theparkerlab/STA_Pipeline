# %% [markdown]
# # Scratchpad

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = r"\\rhea\E\20241028_WT00026R1_M_FM_LIGHT_DMS_angie_ephys_topDLCephys.h5"

# %%
phy_df = pd.read_hdf(file,key='phy_df')

# %%
[len(item) for item in phy_df['spikeT']]
# Out:
# [18296,
#  21631,
#  9972,
#  4085,
#  0,
#  15,
#  271,
#  8392,
#  1654,
#  2149,
#  81,
#  1800,
#  769,
#  697,
#  460,
#  6274,
#  3607,
#  43083,
#  4003,
#  577,
#  0,
#  0,
#  535,
#  159,
#  7682,
#  1868,
#  420,
#  28163,
#  2477,
#  20,
#  3587,
#  4713,
#  1448,
#  26153,
#  3028,
#  13,
#  87,
#  2,
#  500,
#  13567,
#  23,
#  9357,
#  5771,
#  17239,
#  24313,
#  44535,
#  3928,
#  176,
#  17968,
#  21967,
#  17163,
#  4235,
#  2551,
#  6489,
#  10533,
#  98,
#  51301,
#  54512,
#  11366,
#  13795,
#  3606,
#  277,
#  199,
#  14,
#  517,
#  6239,
#  385,
#  465,
#  670,
#  319,
#  278,
#  1947,
#  562,
#  1455,
#  54,
#  225,
#  2097,
#  175,
#  81,
#  32,
#  7868,
#  1649,
#  166,
#  104,
#  339,
#  903,
#  3586,
#  1530,
#  10,
#  5672,
#  1952,
#  9832,
#  785,
#  1,
#  1581,
#  910,
#  135,
#  299,
#  152,
#  940,
#  12726,
#  2146,
#  1662,
#  374,
#  183,
#  258,
#  1317,
#  404,
#  8951,
#  1009,
#  250,
#  842,
#  188,
#  218,
#  215,
#  59,
#  6,
#  101,
# ...

# %%
for index, row in phy_df.iterrows():
    # print(len(row['spikeT']))
    if len(row['spikeT'])==0:
        phy_df = phy_df.drop(index=index)

# %%
phy_df
# Out:
#      Amplitude  ContamPct KSLabel         amp   ch  depth        fr group  \
# 0       1387.2        1.1    good   76.701118    0  775.0  6.085991  good
# 12      1151.6        1.1    good   80.875397    4  675.0  8.866296  good
# 15      1208.5        9.5    good   72.525131    4  675.0  4.195939  good
# 25      2972.3        0.9    good   82.426300    7  600.0  2.816707  good
# 29      2572.1        0.0    good  107.671135    8  575.0  0.050964  good
# ..         ...        ...     ...         ...  ...    ...       ...   ...
# 716     1397.1        4.2    good   67.642578  106  525.0  0.299009  good
# 734     1239.8        9.4    good   66.924431  127    0.0  0.275643  good
# 743     2835.0        0.0    good   89.819740   46  425.0  0.145102  good
# 747      932.7        5.6    good   71.124474   87  200.0  0.713997  good
# 748     3479.3        0.0    good   91.798821   95    0.0  0.111409  good
#
#      n_spikes  sh                                           waveform  \
# ...

# %%
phy_df.to_hdf(file,key='phy_df')
# Out:
# C:\Users\plab\AppData\Local\Temp\ipykernel_27912\1640221239.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['KSLabel', 'group', 'waveform', 'spikeT'], dtype='object')]
#
#   phy_df.to_hdf(file,key='phy_df')

# %%
file = r"\\rhea\E\20241028\WT00026R1\FM_DARK\20241028_WT00026R1_M_FM_DARK_DMS_angie_ephys_merge.json"
phy_df = pd.read_json(file)

# %%
phy_df['spikeT']
# Out:
# 0      [0.3687666667, 0.3982666667, 0.474000000000000...
# 1      [0.6524666667, 0.7655666667000001, 0.912666666...
# 2      [61.8272333333, 64.2741666667, 110.4843666667,...
# 3      [0.0511, 0.42060000000000003, 1.35760000000000...
# 4      [629.8921, 1073.1281, 1142.2690333333, 1462.41...
#                              ...
# 749    [143.2457333333, 417.6937666667, 621.975133333...
# 750    [34.5128, 1758.6926, 1946.5789666667, 1952.041...
# 751    [54.6920333333, 64.5689666667, 66.9665666667, ...
# 752                   [1115.3996666667, 2008.6351333333]
# 753    [63.5951666667, 182.9658333333, 347.9026333333...
# Name: spikeT, Length: 741, dtype: object

# %%
# Out:
# NOTE: Using ebc_angle_bin_size = 3 decreases running time
# 2025-02-11 14:48:02,333	INFO worker.py:1382 -- Calling ray.init() again after it has already been called.
# 0 79719 egocentric head
# 30000 79719 egocentric head
# 60000 79719 egocentric head
# 79719
# d:\Pipeline\STA_Pipeline\bootstrap_ebc_head.py:152: RuntimeWarning: invalid value encountered in divide
#   cell_spikes_avg = np.divide(cell_spikes_avg,ebc_data_avg)
# d:\Pipeline\STA_Pipeline\bootstrap_ebc_head.py:152: RuntimeWarning: invalid value encountered in divide
#   cell_spikes_avg = np.divide(cell_spikes_avg,ebc_data_avg)
# d:\Pipeline\STA_Pipeline\bootstrap_ebc_head.py:152: RuntimeWarning: invalid value encountered in divide
#   cell_spikes_avg = np.divide(cell_spikes_avg,ebc_data_avg)
# d:\Pipeline\STA_Pipeline\bootstrap_ebc_head.py:152: RuntimeWarning: invalid value encountered in divide
#   cell_spikes_avg = np.divide(cell_spikes_avg,ebc_data_avg)
# bootstrap file exists
# bootstrap file exists
# ...

# %%
# Out:
# C:\Users\plab\AppData\Local\Temp\ipykernel_28376\3269577115.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax2 = plt.subplot(121, projection='polar')
# C:\Users\plab\AppData\Local\Temp\ipykernel_28376\3269577115.py:17: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax3 = plt.subplot(122, projection='polar')
